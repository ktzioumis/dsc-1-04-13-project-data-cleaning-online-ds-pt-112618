# %% [markdown]
# # Project - Data Cleaning
#
# ## Introduction
# In this lab, we'll make use of everything we've learned about pandas, data cleaning, and Exploratory Data Analysis. In order to complete this lab, you'll have to make import, clean, combine, reshape, and visualize data to answer questions provided, as well as your own questions!
#
# ## Objectives
# You will be able to:
# * Show mastery of the content covered in this section
#
# ## The Dataset
# In this lab, we'll work with the comprehensive [Super Heroes Dataset](https://www.kaggle.com/claudiodavi/superhero-set/data), which can be found on Kaggle!
#
# ## Goals
# * Use all available pandas knowledge to clean the dataset and deal with null values
# * Use Queries and aggregations to group the data into interesting subsets as needed
# * Use descriptive statistics and data visualization to find answers to questions we may have about the data.
#
# ## Getting Started
#
# In the cell below:
#
# * Import and alias pandas as `pd`
# * Import and alias numpy as `np`
# * Import and alias seaborn as `sns`
# * Import and alias matplotlib.pyplot as `plt`
# * Set matplotlib visualizations to display inline in the notebook

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# For this lab, our dataset is split among two different sources--`heroes_information.csv` and `super_hero_powers.csv`.
#
# Use pandas to read in each file and store them in DataFrames in the appropriate variables below. Then, display the head of each to ensure that everything loaded correctly.

# %%
heroes_df = pd.read_csv('heroes_information.csv')
powers_df = pd.read_csv('super_hero_powers.csv')
heroes_df.head()
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0           0       A-Bomb   Male    yellow              Human    No Hair
# 1           1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2           2     Abin Sur   Male      blue            Ungaran    No Hair
# 3           3  Abomination   Male     green  Human / Radiation    No Hair
# 4           4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics          -      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics          -       bad   441.0
# 4   -99.0      Marvel Comics          -       bad   -99.0

# %%
powers_df.head()
# Out:
#     hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0      3-D Man     True                False               False
# 1       A-Bomb    False                 True               False
# 2   Abe Sapien     True                 True               False
# 3     Abin Sur    False                False                True
# 4  Abomination    False                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True    False
# 2                  False             True        True    False
# 3                  False            False       False    False
# 4                  False            False       False    False
#
#    Energy Absorption  Flight     ...      Web Creation  Reality Warping  \
# 0              False   False     ...             False            False
# ...

# %% [markdown]
# It looks as if the heroes information dataset contained an index column.  We did not specify that this dataset contained an index column, because we hadn't seen it yet. Pandas does not know how to tell apart an index column from any other data, so it stored it with the column name `Unnamed: 0`.
#
# Our DataFrame provided row indices by default, so this column is not needed.  Drop it from the DataFrame in place in the cell below, and then display the head of `heroes_df` to ensure that it worked properly.

# %%
 heroes_df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'Gender', 'Eye color', 'Race', 'Hair color',
#        'Height', 'Publisher', 'Skin color', 'Alignment', 'Weight'],
#       dtype='object')

# %%
heroes_df.drop(columns='Unnamed: 0', inplace=True)
heroes_df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0

# %% [markdown]
# ## Familiarize Yourself With the Dataset
#
# The first step in our Exploratory Data Analysis will be to get familiar with the data.  This step includes:
#
# * Understanding the dimensionality of your dataset
# * Investigating what type of data it contains, and the data types used to store it
# * Discovering how missing values are encoded, and how many there are
# * Getting a feel for what information it does and doesnt contain
#
# In the cell below, get the descriptive statistics of each DataFrame.

# %%
print(heroes_df.info(), heroes_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 10 columns):
# name          734 non-null object
# Gender        734 non-null object
# Eye color     734 non-null object
# Race          734 non-null object
# Hair color    734 non-null object
# Height        734 non-null float64
# Publisher     719 non-null object
# Skin color    734 non-null object
# Alignment     734 non-null object
# Weight        732 non-null float64
# dtypes: float64(2), object(8)
# memory usage: 57.4+ KB
# None            Height      Weight
# count  734.000000  732.000000
# mean   102.254087   43.855191
# std    139.624543  130.823733
# min    -99.000000  -99.000000
# 25%    -99.000000  -99.000000
# 50%    175.000000   62.000000
# 75%    185.000000   90.000000
# max    975.000000  900.000000

# %%
print(powers_df.info(),powers_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Columns: 168 entries, hero_names to Omniscient
# dtypes: bool(167), object(1)
# memory usage: 114.1+ KB
# None        hero_names Agility Accelerated Healing Lantern Power Ring  \
# count         667     667                 667                667
# unique        667       2                   2                  2
# top     Iron Fist   False               False              False
# freq            1     425                 489                656
#
#        Dimensional Awareness Cold Resistance Durability Stealth  \
# count                    667             667        667     667
# unique                     2               2          2       2
# top                    False           False      False   False
# freq                     642             620        410     541
#
#        Energy Absorption Flight    ...     Web Creation Reality Warping  \
# ...

# %% [markdown]
# ## Dealing with Null Values
#
# Starting in the cell below, detect and deal with any null values in either data frame.  Then, explain your methodology for detecting and dealing with outliers in the markdown section below.  Be sure to explain your strategy for dealing with null values in numeric columns, as well as your strategy for dealing with null values in non-numeric columns.
#
# Note that if you need to add more cells to write code in, you can do this by:
#
# **1.** Highlighting a cell and then pressing `ESC` to enter command mode.
# **2.** Press `A` to add a cell above the highlighted cell, or `B` to add a cell below the highlighted cell.
#
# Describe your strategy below this line:
# ____________________________________________________________________________________________________________________________
#
# Publisher contains 15 NaN values. small subset of df of length 734. delete entries (also contains 2 missing weight entries- bonus!)
#
# height and weight columns contain values for -99. this is impossible and can be assumed to be missing value placeholders. weight null entries eliminated in Publisher.dropna()
#
#
# height contains 225 entries with -99 value - too many to want to drop. impute median
#
#
# weight contains 208 entries with -99 value - too many to want to drop. impute median
#
#
# Skin color contains 648 values for '-' as an unknown or not relevant placeholder. column mostly empty lets drop column
#
#
# Gender contains 27 values of '-' and Race contains 297 values of '-' and alignment contains 6 values of '-' these I'm going to leave in place as this is more a feature than a bug for the dataset showing the complexitty of the universes they describe not fitting into neat labels (eyeroll)
#
#
# Hair Color and Eye color each contain 163 entries for '-', object not easily filled with a median or common value. Don't know what would be best there. gonna leave it alone
#
# Powers_df contains no null values woohoo! all values Boolean except for hero_names all are unique so no indication of placeholder values

# %%
heroes_df.isna().sum()
# Out:
# name           0
# Gender         0
# Eye color      0
# Race           0
# Hair color     0
# Height         0
# Publisher     15
# Skin color     0
# Alignment      0
# Weight         2
# dtype: int64

# %%
heroes_df.Publisher.unique()
# Out:
# array(['Marvel Comics', 'Dark Horse Comics', 'DC Comics', 'NBC - Heroes',
#        'Wildstorm', 'Image Comics', nan, 'Icon Comics', 'SyFy',
#        'Hanna-Barbera', 'George Lucas', 'Team Epic TV', 'South Park',
#        'HarperCollins', 'ABC Studios', 'Universal Studios', 'Star Trek',
#        'IDW Publishing', 'Shueisha', 'Sony Pictures', 'J. K. Rowling',
#        'Titan Books', 'Rebellion', 'Microsoft', 'J. R. R. Tolkien'],
#       dtype=object)

# %%
#heroes_df.Publisher.fillna('missing', inplace=True)
#heroes_df.loc[heroes_df['Publisher']=='missing']
#just looking

# %%
heroes_df.dropna(inplace=True)
heroes_df.isna().sum()
#no more null entries!
# Out:
# name          0
# Gender        0
# Eye color     0
# Race          0
# Hair color    0
# Height        0
# Publisher     0
# Skin color    0
# Alignment     0
# Weight        0
# dtype: int64

# %%
print(heroes_df.Weight.value_counts().head(),'\n',heroes_df.Height.value_counts().head())
# Out:
# -99.0    225
#  79.0     23
#  54.0     23
#  81.0     22
#  90.0     19
# Name: Weight, dtype: int64
#  -99.0     208
#  183.0     59
#  188.0     51
#  180.0     38
#  178.0     37
# Name: Height, dtype: int64

# %%
heroes_height_median=heroes_df.Height.loc[heroes_df.Height>0].median()
heroes_height_median
#find median without -99 placeholders
# Out:
# 183.0

# %%
heroes_df.Height.replace(to_replace=-99, value=heroes_height_median,inplace=True)
heroes_df.Height.value_counts().head()
# Out:
# 183.0    267
# 188.0     51
# 180.0     38
# 178.0     37
# 185.0     35
# Name: Height, dtype: int64

# %%
heroes_weight_median=heroes_df.Weight.loc[heroes_df.Weight>0].median()
heroes_weight_median
# Out:
# 81.0

# %%
heroes_df.Weight.replace(to_replace=-99, value=heroes_weight_median,inplace=True)
heroes_df.Weight.value_counts().head()
# Out:
# 81.0    247
# 54.0     23
# 79.0     23
# 90.0     19
# 52.0     15
# Name: Weight, dtype: int64

# %%
heroes_df['Skin color'].value_counts()
# Out:
# -                 649
# green              21
# blue                9
# red                 8
# white               7
# silver              5
# grey                4
# gold                3
# purple              3
# pink                2
# yellow              2
# red / black         1
# orange / white      1
# orange              1
# gray                1
# blue-white          1
# black               1
# Name: Skin color, dtype: int64

# %%
heroes_df.drop(columns='Skin color', inplace=True)
heroes_df.columns
# Out:
# Index(['name', 'Gender', 'Eye color', 'Race', 'Hair color', 'Height',
#        'Publisher', 'Alignment', 'Weight'],
#       dtype='object')

# %%
heroes_df.Gender.value_counts()
# Out:
# Male      494
# Female    198
# -          27
# Name: Gender, dtype: int64

# %%
heroes_df.loc[heroes_df['Gender']=='-']
# Out:
#                  name Gender                Eye color           Race  \
# 87         Bird-Brain      -                        -              -
# 112       Blaquesmith      -                    black              -
# 133           Box III      -                     blue              -
# 134            Box IV      -                    brown              -
# 160  Captain Universe      -                        -  God / Eternal
# 165     Cecilia Reyes      -                    brown              -
# 178              Clea      -                        -              -
# 196            Cypher      -                     blue              -
# 234               Ego      -                        -              -
# 249     Fabian Cortez      -                     blue              -
# 253             Feral      -  yellow (without irises)              -
# 257          Firelord      -                    white              -
# 261             Fixer      -                      red              -
# ...

# %%
heroes_df.Race.value_counts()
# Out:
# -                     297
# Human                 204
# Mutant                 62
# God / Eternal          14
# Human / Radiation      11
# Cyborg                 10
# Android                 9
# Symbiote                9
# Kryptonian              7
# Alien                   7
# Demon                   6
# Asgardian               5
# Atlantean               5
# Alpha                   5
# Inhuman                 4
# Cosmic Entity           4
# Animal                  3
# New God                 3
# Human / Altered         3
# Human-Kree              2
# Saiyan                  2
# Amazon                  2
# Human / Cosmic          2
# Eternal                 2
# Metahuman               2
# Frost Giant             2
# Vampire                 2
# Demi-God                2
# Strontian               1
# Dathomirian Zabrak      1
#                      ...
# Yautja                  1
# Xenomorph XX121         1
# Gungan                  1
# Rodian                  1
# ...

# %%
heroes_df.Alignment.value_counts()
# Out:
# good       484
# bad        205
# neutral     24
# -            6
# Name: Alignment, dtype: int64

# %%
heroes_df['Hair color'].value_counts()
# Out:
# -                   163
# Black               154
# Blond                99
# Brown                85
# No Hair              74
# Red                  51
# White                23
# Auburn               13
# Green                 8
# Strawberry Blond      7
# Grey                  5
# Purple                5
# Brown / White         4
# Silver                4
# Blue                  3
# black                 3
# blond                 3
# Orange                2
# Yellow                2
# Red / Orange          1
# Indigo                1
# Brownn                1
# Brown / Black         1
# Magenta               1
# Red / Grey            1
# Orange / White        1
# Red / White           1
# Gold                  1
# Black / Blue          1
# Pink                  1
# Name: Hair color, dtype: int64

# %%
heroes_df.loc[heroes_df['Hair color']=='-'].head()
# Out:
#                 name Gender Eye color     Race Hair color  Height  \
# 10        Agent Zero   Male         -        -          -   191.0
# 14       Alex Mercer   Male         -    Human          -   183.0
# 15      Alex Woolsly   Male         -        -          -   183.0
# 18  Allan Quatermain   Male         -        -          -   183.0
# 19             Amazo   Male       red  Android          -   257.0
#
#         Publisher Alignment  Weight
# 10  Marvel Comics      good   104.0
# 14      Wildstorm       bad    81.0
# 15   NBC - Heroes      good    81.0
# 18      Wildstorm      good    81.0
# 19      DC Comics       bad   173.0

# %%
heroes_df['Eye color'].value_counts()
# Out:
# blue                       224
# -                          163
# brown                      123
# green                       73
# red                         46
# black                       22
# yellow                      18
# white                       17
# hazel                        6
# grey                         6
# purple                       4
# gold                         3
# amber                        2
# yellow (without irises)      2
# violet                       2
# yellow / blue                1
# indigo                       1
# green / blue                 1
# blue / white                 1
# bown                         1
# white / red                  1
# yellow / red                 1
# silver                       1
# Name: Eye color, dtype: int64

# %%
heroes_df.loc[heroes_df['Eye color']=='-'].head()
# Out:
#                 name Gender Eye color             Race Hair color  Height  \
# 10        Agent Zero   Male         -                -          -   191.0
# 14       Alex Mercer   Male         -            Human          -   183.0
# 15      Alex Woolsly   Male         -                -          -   183.0
# 17             Alien   Male         -  Xenomorph XX121    No Hair   244.0
# 18  Allan Quatermain   Male         -                -          -   183.0
#
#             Publisher Alignment  Weight
# 10      Marvel Comics      good   104.0
# 14          Wildstorm       bad    81.0
# 15       NBC - Heroes      good    81.0
# 17  Dark Horse Comics       bad   169.0
# 18          Wildstorm      good    81.0

# %%
sorted(powers_df.isna().sum(), reverse=False)[:5]
# Out:
# [0, 0, 0, 0, 0]

# %% [markdown]
# ## Joining, Grouping, and Aggregating
#
# In the cell below, join the two DataFrames.  Think about which sort of join you should use, as well as which columns you should join on.  Rename columns and manipulate as needed.
#
# **_HINT:_** If the join throws an error message, consider settin the the column you want to join on as the index for each DataFrame.

# %%
heroes_df_name_index=heroes_df.set_index('name')
heroes_df_name_index.head()
powers_df_name_index=powers_df.rename(columns={'hero_names':'name'}).set_index('name')
powers_df_name_index.head()
heroes_powers=heroes_df_name_index.join(powers_df_name_index,how='inner',)
heroes_powers.head()
# Out:
#             Gender Eye color               Race Hair color  Height  \
# name
# A-Bomb        Male    yellow              Human    No Hair   203.0
# Abe Sapien    Male      blue      Icthyo Sapien    No Hair   191.0
# Abin Sur      Male      blue            Ungaran    No Hair   185.0
# Abomination   Male     green  Human / Radiation    No Hair   203.0
# Abraxas       Male      blue      Cosmic Entity      Black   183.0
#
#                      Publisher Alignment  Weight  Agility  \
# name
# A-Bomb           Marvel Comics      good   441.0    False
# Abe Sapien   Dark Horse Comics      good    65.0     True
# Abin Sur             DC Comics      good    90.0    False
# Abomination      Marvel Comics       bad   441.0    False
# Abraxas          Marvel Comics       bad    81.0    False
#
#              Accelerated Healing     ...      Web Creation  Reality Warping  \
# name                                 ...
# A-Bomb                      True     ...             False            False
# ...

# %% [markdown]
# In the cell below, subset male and female heroes into different dataframes.  Create a scatterplot of the height and weight of each hero, with weight as the y-axis.  Plot both the male and female heroes subset into each dataframe, and make the color for each point in the scatterplot correspond to the gender of the superhero.

# %%
male=heroes_df.loc[heroes_df.Gender=='Male']
female=heroes_df.loc[heroes_df.Gender=='Female']

# %%
plt.scatter(x=male.Height, y=male.Weight, color='blue')
plt.scatter(x=female.Height, y=female.Weight, color='red')
plt.title('Hero Height and Weight by Gender')
plt.legend('MF')
plt.ylabel('Weight')
plt.xlabel('Height')
plt.show()

# %% [markdown]
# ## Some Initial Investigation
#
# Next, slice the DataFrame as needed and visualize the distribution of heights and weights by gender.  You should have 4 total plots.
#
# In the cell below:
#
# * Slice the DataFrame into separate DataFrames by gender
# * Complete the `show_distplot` function.  This helper function should take in a DataFrame, a string containing the gender we want to visualize, and and the column name we want to visualize by gender. The function should display a distplot visualization from seaborn of the column/gender combination.
#
# Hint: Don't forget to check the [seaborn documentation for distplot](https://seaborn.pydata.org/generated/seaborn.distplot.html) if you have questions about how to use it correctly!

# %% [markdown]
# I'm goign to reload the dataframe because I definitely broke this earlier when I imputed medians for height and weight irrespective of gender

# %%
heroes_df2=pd.read_csv('heroes_information.csv')
heroes_df2.head()
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0           0       A-Bomb   Male    yellow              Human    No Hair
# 1           1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2           2     Abin Sur   Male      blue            Ungaran    No Hair
# 3           3  Abomination   Male     green  Human / Radiation    No Hair
# 4           4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics          -      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics          -       bad   441.0
# 4   -99.0      Marvel Comics          -       bad   -99.0

# %%
heroes_df2.drop(columns='Unnamed: 0',inplace=True)
heroes_df2.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0

# %%
heroes_df2.isna().sum()
# Out:
# name           0
# Gender         0
# Eye color      0
# Race           0
# Hair color     0
# Height         0
# Publisher     15
# Skin color     0
# Alignment      0
# Weight         2
# dtype: int64

# %% [markdown]
# convert missing values to place holder = -99

# %%
heroes_df2.Weight.fillna(value=-99, inplace=True)

# %%
heroes_df2.Weight.value_counts().head()
# Out:
# -99.0    239
#  79.0     23
#  54.0     23
#  81.0     22
#  90.0     19
# Name: Weight, dtype: int64

# %%
male_heroes_df = heroes_df2.loc[heroes_df2.Gender=='Male']
female_heroes_df = heroes_df2.loc[heroes_df2.Gender=='Female']

def show_distplot(dataframe, gender, column_name):
    plt.plot()
    sns.distplot(dataframe[column_name])
    plt.title(f'{gender} Heroes {column_name} distribution')
    plt.ylabel('Probability Density')
    plt.show()

# %%
# Male Height
show_distplot(heroes_df2, 'Male', 'Height')
print(f'Mean:{male_heroes_df.Height.mean()}\nMedian:{male_heroes_df.Height.median()}\nMode:{male_heroes_df.Height.mode()}')
# Out:
# C:\Users\kosta\Anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Mean:107.27524752475247
# Median:180.0
# Mode:0   -99.0
# dtype: float64

# %%
# Male Weight
show_distplot(heroes_df2, 'Male', 'Weight')
print(f'Mean:{male_heroes_df.Weight.mean()}\nMedian:{male_heroes_df.Weight.median()}\nMode:{male_heroes_df.Weight.mode()}')
# Out:
# C:\Users\kosta\Anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Mean:51.75247524752475
# Median:79.0
# Mode:0   -99.0
# dtype: float64

# %%
# Female Height
show_distplot(heroes_df2, 'Female', 'Height')
print(f'Mean:{female_heroes_df.Height.mean()}\nMedian:{female_heroes_df.Height.median()}\nMode:{female_heroes_df.Height.mode()}')
# Out:
# C:\Users\kosta\Anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Mean:98.0525
# Median:168.0
# Mode:0   -99.0
# dtype: float64

# %%
# Female Weight
show_distplot(heroes_df2, 'Female', 'Weight')
print(f'Mean:{female_heroes_df.Weight.mean()}\nMedian:{female_heroes_df.Weight.median()}\nMode:{female_heroes_df.Weight.mode()}')
# Out:
# C:\Users\kosta\Anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Mean:27.265
# Median:54.0
# Mode:0   -99.0
# dtype: float64

# %%
heroes_df3=heroes_df2[heroes_df2.Height>0][heroes_df2.Weight>0]
heroes_df3.describe()
# Out:
# C:\Users\kosta\Anaconda3\envs\learn-env\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#            Height      Weight
# count  490.000000  490.000000
# mean   187.123878  112.179592
# std     58.990016  104.422653
# min     15.200000    4.000000
# 25%    173.500000   61.000000
# 50%    183.000000   81.000000
# 75%    188.000000  106.000000
# max    975.000000  900.000000

# %%
male_heroes_df3 = heroes_df3.loc[heroes_df3.Gender=='Male']
female_heroes_df3 = heroes_df3.loc[heroes_df3.Gender=='Female']
print('Male\n',male_heroes_df3.describe(),'\n\n\n','Female\n',female_heroes_df3.describe())
# Out:
# Male
#             Height      Weight
# count  335.000000  335.000000
# mean   192.934925  125.734328
# std     69.147231  111.134613
# min     15.200000    4.000000
# 25%    180.000000   79.000000
# 50%    185.000000   90.000000
# 75%    193.000000  120.500000
# max    975.000000  900.000000
#
#
#  Female
#             Height      Weight
# count  141.000000  141.000000
# mean   173.826241   78.340426
# std     21.581903   77.020761
# min     62.500000   41.000000
# 25%    168.000000   54.000000
# 50%    170.000000   58.000000
# 75%    178.000000   65.000000
# max    366.000000  630.000000

# %%
# Male Height -99 removed
show_distplot(heroes_df3, 'Male', 'Height')
print(f'Mean: {male_heroes_df3.Height.mean()}\nMedian: {male_heroes_df3.Height.median()}\nMode: {male_heroes_df3.Height.mode()}')
# Out:
# C:\Users\kosta\Anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Mean: 192.93492537313432
# Median: 185.0
# Mode: 0    183.0
# dtype: float64

# %%
# Male Weight -99 removed
show_distplot(heroes_df3, 'Male', 'Weight')
print(f'Mean: {male_heroes_df3.Weight.mean()}\nMedian: {male_heroes_df3.Weight.median()}\nMode: {male_heroes_df3.Weight.mode()}')
# Out:
# C:\Users\kosta\Anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Mean: 125.73432835820896
# Median: 90.0
# Mode: 0    79.0
# dtype: float64

# %%
# Female Height -99 removed
show_distplot(heroes_df3, 'Female', 'Height')
print(f'Mean: {female_heroes_df3.Height.mean()}\nMedian: {female_heroes_df3.Height.median()}\nMode: {female_heroes_df3.Height.mode()}')
# Out:
# C:\Users\kosta\Anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Mean: 173.82624113475177
# Median: 170.0
# Mode: 0    168.0
# dtype: float64

# %%
# Female Weight -99 removed
show_distplot(heroes_df3, 'Female', 'Weight')
print(f'Mean: {female_heroes_df3.Weight.mean()}\nMedian: {female_heroes_df3.Weight.median()}\nMode: {female_heroes_df3.Weight.mode()}')
# Out:
# C:\Users\kosta\Anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Mean: 78.34042553191489
# Median: 58.0
# Mode: 0    54.0
# dtype: float64

# %% [markdown]
# Discuss your findings from the plots above, with respect to the distibution of height and weight by gender.  Your explanation should include discussion of any relevant summary statistics, including mean, median, mode, and the overall shape of each distribution.
#
# Wite your answer below this line:
# ____________________________________________________________________________________________________________________________
# two peaks in original distribution graphs for -99 missing value placeholder and for true data
# -99 as numerical value skews mean very heavily and median because there are many values. it is the mode in each case as other values are relatively contniuous
# Male and female Heights are similar, narrow interquartile range although male slightly taller
# weights more distributed, breader peaks, slopes less steep on plots) for both genders. women significantly lower and narrow medians and interquartile ranges.
# overall shape for all graphs has a left hand skew with a long tail out to scattered high value outliers

# %% [markdown]
# ### Sample Question: Most Common Powers
#
# The rest of this notebook will be left to you to investigate the dataset by formulating your own questions, and then seeking answers using pandas and numpy.  Every answer should include some sort of visualization, when appropriate. Before moving on to formulating your own questions, use the dataset to answer the following questions about superhero powers:
#
# * What are the 5 most common powers overall?
# * What are the 5 most common powers in the Marvel Universe?
# * What are the 5 most common powers in the DC Universe?

# %%
heroes_powers.head()
# Out:
#             Gender Eye color               Race Hair color  Height  \
# name
# A-Bomb        Male    yellow              Human    No Hair   203.0
# Abe Sapien    Male      blue      Icthyo Sapien    No Hair   191.0
# Abin Sur      Male      blue            Ungaran    No Hair   185.0
# Abomination   Male     green  Human / Radiation    No Hair   203.0
# Abraxas       Male      blue      Cosmic Entity      Black   183.0
#
#                      Publisher Alignment  Weight  Agility  \
# name
# A-Bomb           Marvel Comics      good   441.0    False
# Abe Sapien   Dark Horse Comics      good    65.0     True
# Abin Sur             DC Comics      good    90.0    False
# Abomination      Marvel Comics       bad   441.0    False
# Abraxas          Marvel Comics       bad    81.0    False
#
#              Accelerated Healing     ...      Web Creation  Reality Warping  \
# name                                 ...
# A-Bomb                      True     ...             False            False
# ...

# %%
Most_Common_Powers=heroes_powers.iloc[:,8:174].sum()
Most_Common_Powers.sort_values(ascending=False).head(5)
# Out:
# Super Strength    357
# Stamina           286
# Durability        256
# Super Speed       248
# Agility           236
# dtype: int64

# %%
Marvel_Universe=heroes_powers[heroes_powers['Publisher']=="Marvel Comics"]
DC_Universe=heroes_powers[heroes_powers['Publisher']=="DC Comics"]
DC_Universe.head()
# Out:
#              Gender Eye color     Race Hair color  Height  Publisher  \
# name
# Abin Sur       Male      blue  Ungaran    No Hair   185.0  DC Comics
# Adam Strange   Male      blue    Human      Blond   185.0  DC Comics
# Alan Scott     Male      blue        -      Blond   180.0  DC Comics
# Amazo          Male       red  Android          -   257.0  DC Comics
# Animal Man     Male      blue    Human      Blond   183.0  DC Comics
#
#              Alignment  Weight  Agility  Accelerated Healing     ...      \
# name                                                             ...
# Abin Sur          good    90.0    False                False     ...
# Adam Strange      good    88.0    False                False     ...
# Alan Scott        good    90.0    False                False     ...
# Amazo              bad   173.0     True                False     ...
# Animal Man        good    83.0    False                False     ...
#
# ...

# %%
print(f'Most common Marvel Universe superpowers:\n{Marvel_Universe.iloc[:,8:174].sum().sort_values(ascending=False).head(5)}\n\n\Most common DC Universe superpowers:\n{DC_Universe.iloc[:,8:174].sum().sort_values(ascending=False).head(5)}')
# Out:
# Most common Marvel Universe superpowers:
# Super Strength    204
# Durability        154
# Stamina           150
# Super Speed       137
# Agility           126
# dtype: int64
#
# \Most common DC Universe superpowers:
# Super Strength    109
# Stamina            90
# Flight             86
# Super Speed        79
# Durability         71
# dtype: int64

# %% [markdown]
# Analyze the results you found above to answer the following question:
#
# How do the top 5 powers in the Marvel and DC universes compare?  Are they similar, or are there significant differences? How do they compare to the overall trends in the entire Superheroes dataset?
#
# Wite your answer below this line:
# ____________________________________________________________________________________________________________________________
#
# Both Marvel and DC have very similar common powers with 4 out of 5 being the same and Marvel's being he same as the overall dataset (it also has more entries though) DC set includes Flight which marvel does not but does not feature Agility.
# All physical characteristics, not a clever bunch
#
#
# ### Your Own Investigation
#
# For the remainder of this lab, you'll be focusing on coming up with and answering your own question, just like we did above.  Your question should not be overly simple, and should require both descriptive statistics and data visualization to answer.  In case you're unsure of what questions to ask, some sample questions have been provided below.
#
# Pick one of the following questions to investigate and answer, or come up with one of your own!
#
# * Which powers have the highest chance of co-occuring in a hero (e.g. super strength and flight), and does this differ by gender?
# * Is there a relationship between a hero's height and weight and their powerset?
# * What is the distribution of skin colors amongst alien heroes?
#
# Explain your question below this line:
# ____________________________________________________________________________________________________________________________
#
#
#
# Some sample cells have been provided to give you room to work. If you need to create more cells, you can do this easily by:
#
# 1. Highlighting a cell and then pressing `esc` to enter command mode.
# 1. Pressing `b` to add a cell below the currently highlighted cell, or `a` to add one above it.
#
# Be sure to include thoughtful, well-labeled visualizations to back up your analysis!

# %%
heroes_powers.iloc[:,8:174].sum(axis=1).sort_values(ascending=False)
# Out:
# name
# Spectre              49
# Amazo                44
# Martian Manhunter    35
# Living Tribunal      35
# Captain Marvel       33
# Man of Miracles      33
# Captain Marvel       33
# T-X                  33
# T-1000               32
# Galactus             32
# Thanos               31
# Odin                 31
# Mister Mxyzptlk      31
# One-Above-All        30
# Wonder Woman         30
# Cable                30
# Dr Manhattan         29
# Franklin Richards    29
# Superman             29
# Darkseid             28
# Supergirl            27
# Alex Mercer          27
# Captain Atom         27
# Legion               26
# Darth Vader          26
# Venompool            26
# Captain Planet       26
# Luke Skywalker       25
# Ultron               25
# Goku                 25
#                      ..
# Big Daddy             1
# Billy Kincaid         1
# Rick Flag             1
# Blink                 1
# Monica Dawson         1
# Mohinder Suresh       1
# Black Knight III      1
# ...

# %% [markdown]
# Spectre has the most powers with 49 (he must be unbearable at parties)

# %%
heroes2powers=heroes_powers.loc[heroes_powers.iloc[:,8:174].sum(axis=1)>1]
heroes2powers.head()
# Out:
#               Gender Eye color               Race Hair color  Height  \
# name
# A-Bomb          Male    yellow              Human    No Hair   203.0
# Abe Sapien      Male      blue      Icthyo Sapien    No Hair   191.0
# Abomination     Male     green  Human / Radiation    No Hair   203.0
# Abraxas         Male      blue      Cosmic Entity      Black   183.0
# Absorbing Man   Male      blue              Human    No Hair   193.0
#
#                        Publisher Alignment  Weight  Agility  \
# name
# A-Bomb             Marvel Comics      good   441.0    False
# Abe Sapien     Dark Horse Comics      good    65.0     True
# Abomination        Marvel Comics       bad   441.0    False
# Abraxas            Marvel Comics       bad    81.0    False
# Absorbing Man      Marvel Comics       bad   122.0    False
#
#                Accelerated Healing     ...      Web Creation  Reality Warping  \
# name                                   ...
# ...

# %%
len(heroes2powers)
#580 out of 674 heroes have more than 1 power
# Out:
# 580

# %%
len(heroes2powers.loc[(heroes2powers['Agility']==True)&(heroes2powers['Accelerated Healing']==True)])
#how many heroes have this coombination of powers? works for 1 example
# Out:
# 106

# %%
def power_matches(df,power1,power2):
    return len(df.loc[(df[power1]==True)&(df[power2]==True)])

# %%
power_matches(heroes2powers,'Agility','Accelerated Healing')
#function works for 1 example!
# Out:
# 106

# %%
def power_match_outer(df):
#     takes df and extracts column names(use slice for power columns only)
    powers=list(df.iloc[:,8:174].columns)
#     create empty dictionary
    power_pairs_dict={}
#         for loop of colum names
    for power1 in powers:
        for power2 in powers:
#         nested for loop of column names again (creates pairs)
#         check for same name
            if power1==power2:
                continue
            else:
                power_pairs_dict[power1+'-'+power2]= power_matches(df,power1,power2)
#         create dictionary key of column name pairing
#         dictionary value for key name pairing = run power_matches on column name pairs and data frame
    return power_pairs_dict
#     output dictionary of column name pairs and frequency as key and value

# %%
power_match_dict=power_match_outer(heroes2powers)
#I cannot believe this worked first go!

# %%
power_match_dict['Agility-Jump']
# Out:
# 42

# %%
#construct a pandas series from dictionary and find highest value
power_pairs_series=pd.Series(power_match_dict)

# %%
power_pairs_series.sort_values(ascending=False).head()
# Out:
# Durability-Super Strength     229
# Super Strength-Durability     229
# Super Speed-Super Strength    221
# Super Strength-Super Speed    221
# Stamina-Super Strength        220
# dtype: int64

# %% [markdown]
# Cool this is absolutely fucking worked!
# Durability and Super Strength are the most common overall power pairing  with 229 occurences (note each pairing occurs twice with the names in the other order. but the values arer the same so i'm goign to call that verification of method)
# Both of these powers are in the top 5 for the dataset and for each of the Marvel and DC subsets so thi sis is an expected result. I ca nsee how they'd be related even. not much use being super strong if youre body is still weak and mushy. Try to punch through a brick wall and you'll just shatter every bone in your hand.

# %% [markdown]
# run this shit over again for male only and female only

# %%
heroes2powers[heroes2powers['Gender']=='Female']
# Out:
#                   Gender Eye color            Race        Hair color  Height  \
# name
# Angel Dust        Female    yellow          Mutant             Black   165.0
# Angel Salvadore   Female     brown               -             Black   163.0
# Arachne           Female      blue           Human             Blond   175.0
# Arclight          Female    violet               -            Purple   173.0
# Ardina            Female     white           Alien            Orange   193.0
# Ariel             Female    purple               -              Pink   165.0
# Armor             Female     black               -             Black   163.0
# Aurora            Female      blue          Mutant             Black   180.0
# Batgirl           Female         -               -                 -   183.0
# Batgirl           Female     green           Human               Red   170.0
# Batgirl IV        Female     green           Human             Black   165.0
# ...

# %%
fem_power_pairs_dict=power_match_outer(heroes2powers[heroes2powers['Gender']=='Female'])
fem_power_pairs_series=pd.Series(fem_power_pairs_dict)
fem_power_pairs_series.sort_values(ascending=False).head()
# Out:
# Super Strength-Super Speed    54
# Super Speed-Super Strength    54
# Durability-Super Strength     52
# Super Strength-Durability     52
# Stamina-Super Strength        51
# dtype: int64

# %%
male_power_pairs_dict=power_match_outer(heroes2powers[heroes2powers['Gender']=='Male'])
male_power_pairs_series=pd.Series(male_power_pairs_dict)
male_power_pairs_series.sort_values(ascending=False).head()
# Out:
# Super Strength-Durability     172
# Durability-Super Strength     172
# Super Strength-Stamina        167
# Stamina-Super Strength        167
# Super Speed-Super Strength    161
# dtype: int64

# %% [markdown]
# Male superheroes match the overall most common power pair at 172
# Female superheroes are more likely to have super strength and super speed but the second most common pairing is super strength and durability which is the 3rd most common pairing for male heroes

# %%
list(heroes2powers.iloc[:,8:175].columns)
# Out:
# ['Agility',
#  'Accelerated Healing',
#  'Lantern Power Ring',
#  'Dimensional Awareness',
#  'Cold Resistance',
#  'Durability',
#  'Stealth',
#  'Energy Absorption',
#  'Flight',
#  'Danger Sense',
#  'Underwater breathing',
#  'Marksmanship',
#  'Weapons Master',
#  'Power Augmentation',
#  'Animal Attributes',
#  'Longevity',
#  'Intelligence',
#  'Super Strength',
#  'Cryokinesis',
#  'Telepathy',
#  'Energy Armor',
#  'Energy Blasts',
#  'Duplication',
#  'Size Changing',
#  'Density Control',
#  'Stamina',
#  'Astral Travel',
#  'Audio Control',
#  'Dexterity',
#  'Omnitrix',
#  'Super Speed',
#  'Possession',
#  'Animal Oriented Powers',
#  'Weapon-based Powers',
#  'Electrokinesis',
#  'Darkforce Manipulation',
#  'Death Touch',
#  'Teleportation',
#  'Enhanced Senses',
#  'Telekinesis',
#  'Energy Beams',
#  'Magic',
#  'Hyperkinesis',
#  'Jump',
#  'Clairvoyance',
#  'Dimensional Travel',
#  'Power Sense',
#  'Shapeshifting',
#  'Peak Human Condition',
#  'Immortality',
# ...

# %% [markdown]
# whoops my slice was too short and I dropped a power. Idon't think it would affect the above investigation b3ecause its not one of the more common powers (Omniscient)

# %% [markdown]
# ## Summary
#
# In this lab, we demonstrated our mastery of:
# * Using all of our Pandas knowledge to date to clean the dataset and deal with null values
# * Using Queries and aggregations to group the data into interesting subsets as needed
# * Using descriptive statistics and data visualization to find answers to questions we may have about the data
